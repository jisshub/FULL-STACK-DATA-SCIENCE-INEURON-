# %% [markdown]
# Dataset Description:
#
# https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
#
#
#     bank.csv

# %%
import pandas as pd 
import numpy as np

# %%
bank_df = pd.read_csv('./datasets/bank-dataset/bank.csv', sep=';')

# %%
bank_df.tail(20)
# Out:
#       age            job   marital  education default  balance housing loan  \
# 4501   34     management   married   tertiary      no      297     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4503   60  self-employed   married    primary      no      362      no  yes
# 4504   42    blue-collar    single  secondary      no     1080     yes  yes
# 4505   32         admin.    single  secondary      no      620     yes   no
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4507   33       services   married  secondary      no      288     yes   no
# 4508   42         admin.   married    unknown      no      642     yes  yes
# 4509   51     technician   married   tertiary      no     2506      no   no
# 4510   36     technician  divorced  secondary      no      566     yes   no
# 4511   46    blue-collar   married  secondary      no      668     yes   no
# ...

# %%
bank_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %% [markdown]
# ## Questions to Solve

# %%
# 1. How many campaigns available in this dataset ?

# %%
sum(bank_df['campaign'])
# Out:
# 12630

# %%
# 2. how many users do we have with personal and housing loan ?

# %%
housing = len(bank_df[bank_df['housing']=='yes'])
loan = len(bank_df[bank_df['loan']=='yes'])
print(housing + loan)
# Out:
# 3250

# %%
# 3. how many person with age > 60 ?.

# %%
len(bank_df['age']>60)
# Out:
# 4521

# %%
# 4. Which month we targeted most of the customer ?

# %%
bank_df['month'].value_counts().index[0]
# Out:
# 'may'

# %%
# 5. Which mode of call gives more result ?

# %%
bank_df['contact'].unique()
# Out:
# array(['cellular', 'unknown', 'telephone'], dtype=object)

# %%
bank_df['contact'].value_counts().head(1)
# Out:
# cellular    2896
# Name: contact, dtype: int64

# %%
# 6. how many entreprenuers we have in the list ?

# %%
bank_df['job'].value_counts()['entrepreneur']
# Out:
# 168

# %%
# 7. how many customers do we have with negative balance ?

# %%
len(bank_df[bank_df['balance']<0])
# Out:
# 366

# %%
# 8. prepare a group of data based on education level.

# %%
bank_df.groupby(['education']).count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
bank_df[['education']]
# Out:
#       education
# 0       primary
# 1     secondary
# 2      tertiary
# 3      tertiary
# 4     secondary
# ...         ...
# 4516  secondary
# 4517   tertiary
# 4518  secondary
# 4519  secondary
# 4520   tertiary
#
# [4521 rows x 1 columns]
